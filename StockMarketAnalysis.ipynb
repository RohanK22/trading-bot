# %%
import numpy as np 
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
stock_data = pd.read_csv('./INFY.csv')
stock_data.head(4)
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  3.471580e+09          75335          3052819                   83.67
# 1  2.920775e+09          71808          1858063                   60.62
# 2  1.384110e+09          75429           792251                   54.35
# 3  3.878282e+09         120990          2309450                   57.32

# %%
stock_data.Series.unique()
# Out:
# array(['EQ', 'BL'], dtype=object)

# %%
stock_data[stock_data.Series == 'BL']
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 444   INFY     BL  25-Feb-2019     1220.15      734.95      734.95     734.95
# 462   INFY     BL  22-Mar-2019      734.95      738.95      738.95     738.95
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 444      734.95       734.95         734.95                1263230
# 462      738.95       738.95         738.95                1727935
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 444  9.284109e+08              1                0                     0.0
# 462  1.276858e+09              1          1727935                   100.0

# %%
# Taking all rows which have 'EQ' in Series columns
stock_data = stock_data[stock_data.Series == 'EQ']

# To ensure only category in Series Columns
stock_data.Series.unique()
# Out:
# array(['EQ'], dtype=object)

# %%
stock_data.tail(4)
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 492   INFY     EQ  08-May-2019      724.55      721.00      726.00      716.5
# 493   INFY     EQ  09-May-2019      719.35      719.15      730.30      715.8
# 494   INFY     EQ  10-May-2019      721.05      720.80      726.00      715.0
# 495   INFY     EQ  13-May-2019      716.85      716.55      726.45      712.1
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 492      718.95       719.35         721.65                6247642
# 493      722.00       721.05         724.48                7396525
# 494      716.50       716.85         717.88                8352335
# 495      718.00       719.70         720.09                6808993
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 492  4.508603e+09         162077          3950857                   63.24
# 493  5.358635e+09         242225          4808832                   65.01
# 494  5.995942e+09         181229          5545377                   66.39
# 495  4.903098e+09         201194          4745909                   69.70

# %%
stock_data.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  3.471580e+09          75335          3052819                   83.67
# 1  2.920775e+09          71808          1858063                   60.62
# 2  1.384110e+09          75429           792251                   54.35
# 3  3.878282e+09         120990          2309450                   57.32
# 4  2.031155e+09          88897          1457747                   68.48

# %%
stock_data.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   494.000000   494.000000   494.000000   494.000000   494.000000
# mean    961.440789   961.070040   971.092713   951.052733   960.845648
# std     220.761549   220.091227   222.968974   218.714372   220.968590
# min     619.100000   621.000000   628.000000   599.850000   619.500000
# 25%     735.025000   736.187500   742.700000   729.012500   734.125000
# 50%     956.750000   957.525000   964.775000   948.000000   956.025000
# 75%    1150.150000  1145.412500  1161.675000  1135.962500  1147.950000
# max    1441.100000  1449.000000  1467.900000  1430.000000  1440.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   494.000000     494.000000           4.940000e+02  4.940000e+02
# mean    960.945749     961.166498           6.056365e+06  5.469840e+09
# std     221.029267     221.102384           5.451445e+06  4.770342e+09
# min     619.100000     613.780000           5.457170e+05  5.060941e+08
# 25%     734.462500     735.720000           3.148044e+06  3.350973e+09
# 50%     955.975000     955.060000           4.905804e+06  4.601808e+09
# 75%    1150.150000    1148.280000           7.303918e+06  6.042062e+09
# max    1441.100000    1451.300000           8.220248e+07  7.662502e+10
#
#        No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# count   4.940000e+02     4.940000e+02              494.000000
# mean    1.361482e+05     3.605878e+06               61.759008
# std     8.557589e+04     2.840733e+06                9.924135
# min     1.388600e+04     3.077410e+05               26.380000
# 25%     9.246300e+04     2.064895e+06               55.142500
# 50%     1.197605e+05     3.053880e+06               62.270000
# 75%     1.551745e+05     4.332777e+06               68.767500
# max     1.192900e+06     4.202849e+07               88.700000

# %%
import pandas as pd
stock_data = pd.read_csv('./week2.csv', index_col=0)
stock_data.head()
# Out:
#   Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ  2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ  2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ  2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ  2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month  Day_Perc_Change                Trend
# 0      5         0.000000  Slight or No change
# 1      5         0.362566  Slight or No change
# 2      5        -0.230366  Slight or No change
# 3      5         0.939337      Slight positive
# 4      5        -0.395113  Slight or No change

# %%
stock_data = stock_data.set_index('Date')
stock_data.head()
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15   INFY     EQ      964.25       963.5      963.50     949.10
# 2017-05-16   INFY     EQ      951.55       953.1      960.15     946.95
# 2017-05-17   INFY     EQ      955.00       951.6      958.45     943.85
# 2017-05-18   INFY     EQ      952.80       943.0      973.90     942.85
# 2017-05-19   INFY     EQ      961.75       961.5      962.70     947.85
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15      953.25       951.55         951.49                3648582
# 2017-05-16      956.00       955.00         952.92                3065084
# 2017-05-17      952.90       952.80         949.48                1457754
# 2017-05-18      960.25       961.75         962.61                4028924
# 2017-05-19      957.40       957.95         954.18                2128698
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# Date
# 2017-05-15  3.471580e+09          75335          3052819
# 2017-05-16  2.920775e+09          71808          1858063
# 2017-05-17  1.384110e+09          75429           792251
# 2017-05-18  3.878282e+09         120990          2309450
# 2017-05-19  2.031155e+09          88897          1457747
#
#             % Dly Qt to Traded Qty  Year  Month  Day_Perc_Change  \
# Date
# 2017-05-15                   83.67  2017      5         0.000000
# 2017-05-16                   60.62  2017      5         0.362566
# 2017-05-17                   54.35  2017      5        -0.230366
# 2017-05-18                   57.32  2017      5         0.939337
# 2017-05-19                   68.48  2017      5        -0.395113
#
#                           Trend
# Date
# 2017-05-15  Slight or No change
# 2017-05-16  Slight or No change
# 2017-05-17  Slight or No change
# 2017-05-18      Slight positive
# 2017-05-19  Slight or No change

# %%
# Importing necessary package
import matplotlib.pyplot as plt 

# Needed for jupyter notebooks
# %matplotlib inline 

# Using the fivethirtyeight matplotlib theme
plt.style.use('fivethirtyeight')

# %%
stock_data.plot(y="Close Price", title="Closing Price of Stock", grid=True, legend=False, linewidth=1, figsize=(10,5))
plt.show()

# %%
drastic_change_df = stock_data[(stock_data.Month==9) & (stock_data.Year==2018)].head(2)
drastic_change_df.style.apply(lambda x:['background: #d65f5f' if x.name=="Close Price" else '' for i in x])
# Out:
# <style  type="text/css" >
# #T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col7,#T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col7{
#             background:  #d65f5f;
#         }</style><table id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Symbol</th>        <th class="col_heading level0 col1" >Series</th>        <th class="col_heading level0 col2" >Prev Close</th>        <th class="col_heading level0 col3" >Open Price</th>        <th class="col_heading level0 col4" >High Price</th>        <th class="col_heading level0 col5" >Low Price</th>        <th class="col_heading level0 col6" >Last Price</th>        <th class="col_heading level0 col7" >Close Price</th>        <th class="col_heading level0 col8" >Average Price</th>        <th class="col_heading level0 col9" >Total Traded Quantity</th>        <th class="col_heading level0 col10" >Turnover</th>        <th class="col_heading level0 col11" >No. of Trades</th>        <th class="col_heading level0 col12" >Deliverable Qty</th>        <th class="col_heading level0 col13" >% Dly Qt to Traded Qty</th>        <th class="col_heading level0 col14" >Year</th>        <th class="col_heading level0 col15" >Month</th>        <th class="col_heading level0 col16" >Day_Perc_Change</th>        <th class="col_heading level0 col17" >Trend</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314level0_row0" class="row_heading level0 row0" >2018-09-03</th>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col0" class="data row0 col0" >INFY</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col1" class="data row0 col1" >EQ</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col2" class="data row0 col2" >1441.100000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col3" class="data row0 col3" >1449.000000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col4" class="data row0 col4" >1467.900000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col5" class="data row0 col5" >1430.000000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col6" class="data row0 col6" >1436.200000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col7" class="data row0 col7" >1434.250000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col8" class="data row0 col8" >1451.300000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col9" class="data row0 col9" >5488164</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col10" class="data row0 col10" >7964966272.700000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col11" class="data row0 col11" >134643</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col12" class="data row0 col12" >3571594</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col13" class="data row0 col13" >65.080000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col14" class="data row0 col14" >2018</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col15" class="data row0 col15" >9</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col16" class="data row0 col16" >-0.475331</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row0_col17" class="data row0 col17" >Slight or No change</td>
#             </tr>
#             <tr>
#                         <th id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314level0_row1" class="row_heading level0 row1" >2018-09-04</th>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col0" class="data row1 col0" >INFY</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col1" class="data row1 col1" >EQ</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col2" class="data row1 col2" >1434.250000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col3" class="data row1 col3" >722.000000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col4" class="data row1 col4" >748.500000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col5" class="data row1 col5" >716.000000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col6" class="data row1 col6" >733.000000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col7" class="data row1 col7" >737.150000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col8" class="data row1 col8" >739.040000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col9" class="data row1 col9" >15370124</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col10" class="data row1 col10" >11359156598.750000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col11" class="data row1 col11" >258728</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col12" class="data row1 col12" >6954062</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col13" class="data row1 col13" >45.240000</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col14" class="data row1 col14" >2018</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col15" class="data row1 col15" >9</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col16" class="data row1 col16" >-48.603800</td>
#                         <td id="T_e02f585b_3ac7_11eb_a98f_1008b1c66314row1_col17" class="data row1 col17" >Bear drop</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(10,5))
markerline, stemlines, baseline = plt.stem(stock_data.index, stock_data.Day_Perc_Change, linefmt='-.', use_line_collection=True)
plt.setp(stemlines, 'linewidth', 1)
plt.title("Daily Change in Stock Price(%)")
plt.xlabel("Dates")
plt.ylabel("Daily Change (%)")
plt.xticks(rotation=45)
plt.show()

# %%
stock_data[stock_data.Day_Perc_Change == min(stock_data.Day_Perc_Change)]
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2018-09-04   INFY     EQ     1434.25       722.0       748.5      716.0
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2018-09-04       733.0       737.15         739.04               15370124
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# Date
# 2018-09-04  1.135916e+10         258728          6954062
#
#             % Dly Qt to Traded Qty  Year  Month  Day_Perc_Change      Trend
# Date
# 2018-09-04                   45.24  2018      9         -48.6038  Bear drop

# %%
stock_data.plot(y="Total Traded Quantity", title="Daily volumes", linewidth=1, figsize=(10,5))
# plt.xlabel("Date")
plt.show()

# %%
with plt.style.context(plt.style.available[23]):
    plt.figure(figsize=(15,25))
    markerline, stemlines, baseline = plt.stem(stock_data.index, stock_data.Day_Perc_Change,label="Day_Perc_Change(%)", use_line_collection=True)
    plt.setp(stemlines, 'linewidth', 1)
    plt.plot(stock_data.index, stock_data["Total Traded Quantity"].values/7000000, color='k', linewidth=1, label="Volume")
    plt.xlabel("Date")
    plt.legend()
    plt.show()

# %%
stock_data_trendwise = stock_data.groupby('Trend')

# %%
stock_data_trendwise.size().plot.pie(figsize=(8,8),autopct='%1.1f%%', startangle=30, radius=1)
plt.ylabel('Trends')
plt.show()

# %%
mean_median = stock_data_trendwise['Total Traded Quantity'].agg(['mean', 'median'])

# %%
mean_median[['mean','median']].plot(kind='bar', subplots=True, figsize=(15,15))
plt.show()

# %%
Category_bins = [stock_data.Day_Perc_Change.min(), -7, -3, -1, -0.5, 0.5, 1, 3, 7]

# %%
stock_data.Day_Perc_Change.hist(bins=Category_bins, edgecolor='k', log=False, figsize=(15,5), rwidth=0.95)
plt.title('Daily Return (%)')
plt.ylabel('Counts of bins')
plt.xlabel('Daily Percentage Change')
plt.show()

# %%
 plt.show()

# %%
# Reading and Importing nifty csv file
nifty50 = pd.read_csv('./Nifty50.csv')

# Convert the Date column to datatime64[ns] datatype
nifty50.Date = pd.to_datetime(nifty50.Date)

# Convert the Date column as index column
nifty50.set_index('Date', inplace=True)

# Calculate the percentage change for Closing price of nifty50
nifty50_pct_change = nifty50.Close.pct_change().dropna()

# Calculate the volatility for nifty50
nifty50_volatility = nifty50_pct_change.rolling(7).std().shift().dropna()

nifty50_volatility.head()
# Out:
# Date
# 2017-05-25    0.005509
# 2017-05-26    0.008139
# 2017-05-29    0.008831
# 2017-05-30    0.007363
# 2017-05-31    0.007268
# Name: Close, dtype: float64

# %%
nifty50_volatility.plot(figsize=(13,7), linewidth=1.3, title='standard deviation of rolling function')
plt.show()

# %%
 stock_data['SMA_14'] = stock_data['Average Price'].rolling(14).mean()
# Calculating Standard deviation for 14 days
stock_data['SD_14'] = stock_data['Average Price'].rolling(14).std()

# %%
# Upper Bollinger Bands = Mean + 2*SD
stock_data['upper_band'] = stock_data.SMA_14 + 2*stock_data.SD_14
# Lower Bollinger Bands = Mean - 2*SD
stock_data['lower_band'] = stock_data.SMA_14 - 2*stock_data.SD_14

# %%
# plt.figure(figsize=(15,10))
stock_data[['SMA_14', 'upper_band', 'lower_band']].plot(figsize=(15,10), linewidth=1, color=['b', 'g', 'r'])
stock_data['Average Price'].plot(figsize=(15,10), linewidth=2.5, color='k')
plt.title("Bollinger Bands")
plt.ylabel('Price in Rupees')
plt.xticks(rotation=45)
plt.show()
